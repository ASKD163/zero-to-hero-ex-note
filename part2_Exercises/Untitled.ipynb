# %%
import torch

# %%
a = torch.tensor([[1,2,3],[3,4,5]])

# %%
a = a.view(1,2,3)
a
# Out:
# tensor([[[1, 2, 3],
#          [3, 4, 5]]])

# %%
a.shape
# Out:
# torch.Size([1, 2, 3])

# %%
a.stride()
# Out:
# (6, 3, 1)

# %%
a.dtype
# Out:
# torch.int64

# %%
torch.mm(a[1], a[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 torch.mm(a[1], a[0])
#
# IndexError: index 1 is out of bounds for dimension 0 with size 1

# %%
a = torch.arange(4).vew(2,2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 a = torch.arange(4).vew(2,2)
#
# AttributeError: 'Tensor' object has no attribute 'vew'
